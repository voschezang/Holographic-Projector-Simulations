# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize
import scipy.linalg
# import scipy.signal
import scipy.fft as spfft
# import scipy.ndimage as spimg
# import cvxpy as cvx
from importlib import reload

import util, plot
from util import *

# %%
m = 5 ** 2
rows, cols = orthogonal(m**2)
rows, cols = sample_dicretized(rows, cols)
plt.scatter(rows, cols, s=2, c='0')

# %%
np.stack([*sample_dicretized(rows, cols)]).T.shape
# Out:
# (625, 2)

# %%
plt.scatter(*np.random.random(size=(2,m**2)), s=2, c='0')

# %%
# rows, cols = np.random.random(0, 0.1, size=(2,100))
# rows += np.arange(100)
# cols += np.arange(100)
# plt.scatter(rows, cols, s=2, c='0')
# indices = np.repeat(np.arange(10), 100)
# rows, cols = np.unravel_index(indices, (10,10))
indices, subspace_shape = stratified(m ** 2, m)
rows, cols = np.unravel_index(indices, subspace_shape)
sample_dicretized(rows, cols, subspace_shape[0])
print(subspace_shape)
plt.scatter(rows, cols, s=2, c='0')
# Out:
# (5, 5)

# %%
DIMS = 2
